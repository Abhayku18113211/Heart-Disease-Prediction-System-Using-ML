# %%
# Import the necessary libraries

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Create the NumPy array for actual and predicted labels

# %%
actual = np.array(
['Patient','Patient','Patient','Not Patient','Patient','Not Patient','Patient','Patient','Not Patient','Not Patient'])
predicted = np.array(
['Patient','Not Patient','Patient','Not Patient','Patient','Patient','Patient','Patient','Not Patient','Not Patient'])

# %%
#Compute the confusion matrix

# %%
cm = confusion_matrix(actual,predicted)

# %%
# Plot the confusion matrix with the help of the seaborn heatmap

# %%
sns.heatmap(cm, 
			annot=True,
			fmt='g', 
			xticklabels=['Patient','Not Patient'],
			yticklabels=['Patient','Not Patient'])
plt.ylabel('Prediction',fontsize=13)
plt.xlabel('Actual',fontsize=13)
plt.title('Confusion Matrix',fontsize=17)
plt.show()
